# %%
import pandas as pd
import numpy as np

df = pd.read_csv("missing_data_replace_practice.csv")

df
# Out:
#       Name            Age           City         Salary     Experience  \
# 0  Nischal             21      Kathmandu          50000              1
# 1   Aayush             22        Pokhara          45000              2
# 2     Sita  Not Available         Butwal            NaN              1
# 3      Ram             20  Not Available          52000  Not Available
# 4     Hari             23       Lalitpur  Not Available              3
# 5     Gita           n.a.           n.a.          48000              2
# 6    Suman             22     Biratnagar           n.a.           n.a.
# 7    Nabin            NaN         Dharan          47000            NaN
# 8     Rita             21            NaN          51000              2
# 9    Kiran             24      Bhaktapur            NaN              3
#
#       Department         Rating          Bonus        Project         Status
# 0             IT            4.5           5000              A         Active
# ...
